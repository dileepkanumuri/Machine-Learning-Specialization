# %% [markdown]
# # TASK #1: UNDERSTAND THE PROBLEM STATEMENT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES AND DATASETS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from jupyterthemes import jtplot
jtplot.style(theme = 'monokai', context = 'notebook', ticks = True, grid = False) 
# setting the style of the notebook to be monokai theme  
# this line of code is important to ensure that we are able to see the x and y axes clearly
# If you don't run this code line, you will notice that the xlabel and ylabel on any plot is black on black and it will be hard to see them.

# %%
# read the csv file 
insurance_df = pd.read_csv('insurance.csv')

# %%
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # TASK #3: PERFORM EXPLORATORY DATA ANALYSIS - PART 1

# %%
# check if there are any Null values
sns.heatmap(insurance_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")

# %%
# check if there are any Null values
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Check the dataframe info

insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Grouping by region to see any relationship between region and charges
# Seems like south east region has the highest charges and body mass index
df_region = insurance_df.groupby(by='region').mean()
df_region
# Out:
#                  age        bmi  children       charges
# region
# northeast  39.268519  29.173503  1.046296  13406.384516
# northwest  39.196923  29.199785  1.147692  12417.575374
# southeast  38.939560  33.355989  1.049451  14735.411438
# southwest  39.455385  30.596615  1.141538  12346.937377

# %% [markdown]
# **PRACTICE OPPORTUNITY #1 [OPTIONAL]:**
# - **Group data by 'age' and examine the relationship between 'age' and 'charges'**

# %% [markdown]
# # TASK #4: PERFORM FEATURE ENGINEERING

# %%
# Check unique values in the 'sex' column
insurance_df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# convert categorical variable to numerical
insurance_df['sex'] = insurance_df['sex'].apply(lambda x: 0 if x == 'female' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
# Check the unique values in the 'smoker' column
insurance_df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
# Convert categorical variable to numerical 
insurance_df['smoker'] = insurance_df['smoker'].apply(lambda x: 0 if x == 'no' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
# Check unique values in 'region' column
insurance_df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_dummies = pd.get_dummies(insurance_df['region'], drop_first = True)

# %%
region_dummies
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
insurance_df = pd.concat([insurance_df, region_dummies], axis = 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges  northwest  \
# 0   19    0  27.900         0       1  southwest  16884.92400          0
# 1   18    1  33.770         1       0  southeast   1725.55230          0
# 2   28    1  33.000         3       0  southeast   4449.46200          0
# 3   33    1  22.705         0       0  northwest  21984.47061          1
# 4   32    1  28.880         0       0  northwest   3866.85520          1
#
#    southeast  southwest
# 0          0          1
# 1          1          0
# 2          1          0
# 3          0          0
# 4          0          0

# %%
# Let's drop the original 'region' column 
insurance_df.drop(['region'], axis = 1, inplace = True)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker      charges  northwest  southeast  \
# 0   19    0  27.900         0       1  16884.92400          0          0
# 1   18    1  33.770         1       0   1725.55230          0          1
# 2   28    1  33.000         3       0   4449.46200          0          1
# 3   33    1  22.705         0       0  21984.47061          1          0
# 4   32    1  28.880         0       0   3866.85520          1          0
#
#    southwest
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# # TASK #5: PERFORM DATA VISUALIZATION

# %%
insurance_df[['age', 'sex', 'bmi', 'children', 'smoker', 'charges']].hist(bins = 30, figsize = (12, 12), color = 'r');

# %%
# plot pairplot
sns.pairplot(insurance_df)

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'age', y = 'charges', data = insurance_df)
plt.show()

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'bmi', y = 'charges', data = insurance_df)
plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #2 [OPTIONAL]:**
#  - **Calculate and plot the correlation matrix**
#  - **Which feature has the most positive correlation with charges?**

# %% [markdown]
# # TASK #6: CREATE TRAINING AND TESTING DATASET

# %%
insurance_df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges', 'northwest',
#        'southeast', 'southwest'],
#       dtype='object')

# %%
X = insurance_df.drop(columns =['charges'])
y = insurance_df['charges']

# %%
X
# Out:
#       age  sex     bmi  children  smoker  northwest  southeast  southwest
# 0      19    0  27.900         0       1          0          0          1
# 1      18    1  33.770         1       0          0          1          0
# 2      28    1  33.000         3       0          0          1          0
# 3      33    1  22.705         0       0          1          0          0
# 4      32    1  28.880         0       0          1          0          0
# ...   ...  ...     ...       ...     ...        ...        ...        ...
# 1333   50    1  30.970         3       0          1          0          0
# 1334   18    0  31.920         0       0          0          0          0
# 1335   18    0  36.850         0       0          0          1          0
# 1336   21    0  25.800         0       0          0          0          1
# 1337   61    0  29.070         0       1          1          0          0
#
# [1338 rows x 8 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
X.shape
# Out:
# (1338, 8)

# %%
y.shape
# Out:
# (1338,)

# %%
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

# %%
y = y.reshape(-1,1)

# %%
# Only take the numerical variables and scale them
X
# Out:
# array([[19.  ,  0.  , 27.9 , ...,  0.  ,  0.  ,  1.  ],
#        [18.  ,  1.  , 33.77, ...,  0.  ,  1.  ,  0.  ],
#        [28.  ,  1.  , 33.  , ...,  0.  ,  1.  ,  0.  ],
#        ...,
#        [18.  ,  0.  , 36.85, ...,  0.  ,  1.  ,  0.  ],
#        [21.  ,  0.  , 25.8 , ...,  0.  ,  0.  ,  1.  ],
#        [61.  ,  0.  , 29.07, ...,  1.  ,  0.  ,  0.  ]], dtype=float32)

# %%
#scaling the data before feeding the model
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_x = StandardScaler()
X = scaler_x.fit_transform(X)

scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 [OPTIONAL]:**
# - **Split the data into 20% Testing and 80% Training**
# - **Double check that the split was successful by getting the shape of both the training and testing datasets**

# %% [markdown]
# # TASK #7: TRAIN AND EVALUATE A LINEAR REGRESSION MODEL IN SCIKIT-LEARN

# %%
# using linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

regresssion_model_sklearn = LinearRegression()
regresssion_model_sklearn.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regresssion_model_sklearn_accuracy = regresssion_model_sklearn.score(X_test, y_test)
regresssion_model_sklearn_accuracy
# Out:
# 0.695328624132532

# %%
y_predict = regresssion_model_sklearn.predict(X_test)

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 268

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt


RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 6536.847
# MSE = 42730372.0
# MAE = 4555.099
# R2 = 0.6953286332761694
# Adjusted R2 = 0.6859179346901052

# %% [markdown]
# # TASK #8: TRAIN AND EVALUATE AN ARTIFICIAL NEURAL NETWORK-BASED REGRESSION MODEL

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 8))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 50)                450
# _________________________________________________________________
# activation (Activation)      (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 150)               7650
# _________________________________________________________________
# activation_1 (Activation)    (None, 150)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 150)               22650
# _________________________________________________________________
# activation_2 (Activation)    (None, 150)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                7550
# _________________________________________________________________
# activation_3 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 38,351
# Trainable params: 38,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
ANN_model.compile(optimizer='Adam', loss='mean_squared_error')

epochs_hist = ANN_model.fit(X_train, y_train, epochs = 100, batch_size = 20, validation_split = 0.2)
# Out:
# Train on 856 samples, validate on 214 samples
# Epoch 1/100
# 856/856 [==============================] - 4s 4ms/sample - loss: 0.4348 - val_loss: 0.2293
# Epoch 2/100
# 856/856 [==============================] - 0s 229us/sample - loss: 0.1662 - val_loss: 0.1603
# Epoch 3/100
# 856/856 [==============================] - 0s 185us/sample - loss: 0.1416 - val_loss: 0.1637
# Epoch 4/100
# 856/856 [==============================] - 0s 195us/sample - loss: 0.1331 - val_loss: 0.1912
# Epoch 5/100
# 856/856 [==============================] - 0s 173us/sample - loss: 0.1356 - val_loss: 0.1849
# Epoch 6/100
# 856/856 [==============================] - 0s 171us/sample - loss: 0.1238 - val_loss: 0.1723
# Epoch 7/100
# 856/856 [==============================] - 0s 169us/sample - loss: 0.1177 - val_loss: 0.1775
# Epoch 8/100
# 856/856 [==============================] - 0s 251us/sample - loss: 0.1247 - val_loss: 0.1762
# Epoch 9/100
# 856/856 [==============================] - 0s 266us/sample - loss: 0.1124 - val_loss: 0.1801
# Epoch 10/100
# 856/856 [==============================] - 0s 327us/sample - loss: 0.1147 - val_loss: 0.1900
# Epoch 11/100
# 856/856 [==============================] - 0s 305us/sample - loss: 0.1093 - val_loss: 0.1886
# Epoch 12/100
# 856/856 [==============================] - 0s 214us/sample - loss: 0.1061 - val_loss: 0.1869
# Epoch 13/100
# 856/856 [==============================] - 0s 203us/sample - loss: 0.1021 - val_loss: 0.1914
# Epoch 14/100
# 856/856 [==============================] - 0s 206us/sample - loss: 0.1050 - val_loss: 0.2009
# Epoch 15/100
# 856/856 [==============================] - 0s 199us/sample - loss: 0.1013 - val_loss: 0.1967
# Epoch 16/100
# 856/856 [==============================] - 0s 171us/sample - loss: 0.0946 - val_loss: 0.1858
# Epoch 17/100
# 856/856 [==============================] - 0s 174us/sample - loss: 0.0921 - val_loss: 0.1984
# Epoch 18/100
# 856/856 [==============================] - 0s 232us/sample - loss: 0.0916 - val_loss: 0.2263
# Epoch 19/100
# 856/856 [==============================] - 0s 261us/sample - loss: 0.1004 - val_loss: 0.1980
# Epoch 20/100
# Epoch 79/100
# 856/856 [==============================] - 0s 279us/sample - loss: 0.0314 - val_loss: 0.2554
# Epoch 80/100
# 856/856 [==============================] - 0s 263us/sample - loss: 0.0321 - val_loss: 0.2454
# Epoch 81/100
# 856/856 [==============================] - 0s 239us/sample - loss: 0.0305 - val_loss: 0.2621
# Epoch 82/100
# 856/856 [==============================] - 0s 236us/sample - loss: 0.0321 - val_loss: 0.2772
# Epoch 83/100
# 856/856 [==============================] - 0s 285us/sample - loss: 0.0364 - val_loss: 0.2624
# Epoch 84/100
# 856/856 [==============================] - 0s 250us/sample - loss: 0.0307 - val_loss: 0.2633
# Epoch 85/100
# 856/856 [==============================] - 0s 255us/sample - loss: 0.0303 - val_loss: 0.2635
# Epoch 86/100
# 856/856 [==============================] - 0s 306us/sample - loss: 0.0284 - val_loss: 0.2629
# Epoch 87/100
# 856/856 [==============================] - 0s 227us/sample - loss: 0.0297 - val_loss: 0.2581
# Epoch 88/100
# 856/856 [==============================] - 0s 326us/sample - loss: 0.0269 - val_loss: 0.2525
# Epoch 89/100
# 856/856 [==============================] - 0s 277us/sample - loss: 0.0254 - val_loss: 0.2512
# Epoch 90/100
# 856/856 [==============================] - 0s 237us/sample - loss: 0.0260 - val_loss: 0.2522
# Epoch 91/100
# 856/856 [==============================] - 0s 243us/sample - loss: 0.0267 - val_loss: 0.2341
# Epoch 92/100
# 856/856 [==============================] - 0s 203us/sample - loss: 0.0259 - val_loss: 0.2747
# Epoch 93/100
# 856/856 [==============================] - 0s 201us/sample - loss: 0.0321 - val_loss: 0.2574
# Epoch 94/100
# 856/856 [==============================] - 0s 174us/sample - loss: 0.0290 - val_loss: 0.2555
# Epoch 95/100
# 856/856 [==============================] - 0s 227us/sample - loss: 0.0287 - val_loss: 0.2647
# Epoch 96/100
# 856/856 [==============================] - 0s 314us/sample - loss: 0.0279 - val_loss: 0.2731
# Epoch 97/100
# 856/856 [==============================] - 0s 215us/sample - loss: 0.0328 - val_loss: 0.2723
# Epoch 98/100
# 856/856 [==============================] - 0s 276us/sample - loss: 0.0276 - val_loss: 0.2545
# Epoch 99/100
# 856/856 [==============================] - 0s 251us/sample - loss: 0.0291 - val_loss: 0.2575
# Epoch 100/100
# 856/856 [==============================] - 0s 234us/sample - loss: 0.0272 - val_loss: 0.2537

# %%
result = ANN_model.evaluate(X_test, y_test)
accuracy_ANN = 1 - result
print("Accuracy : {}".format(accuracy_ANN))
# Out:
# 268/268 [==============================] - 0s 131us/sample - loss: 0.2770
# Accuracy : 0.7230018083728962

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
y_predict = ANN_model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
k = X_test.shape[1]
n = len(X_test)
n

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 6371.192
# MSE = 40592084.0
# MAE = 3941.715
# R2 = 0.7105748321375387
# Adjusted R2 = 0.7016350586128295

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 [OPTIONAL]:**
# - **Dropout is a regularization technique that is used to improve the network generalization ability. Experiment adding dropout layers to enahnce network generalization ability**
# - **Retrain the network and assess its performance**

# %% [markdown]
# # GREAT JOB!

# %% [markdown]
# # PRACTICE OPPORTUNITY SOLUTIONS

# %% [markdown]
# **PRACTICE OPPORTUNITY #1 SOLUTION:**
# - **Group data by 'age' and examine the relationship between 'age' and 'charges'**

# %%
df_age = insurance_df.groupby(by = 'age').mean()
df_age
# Out:
#           sex        bmi  children    smoker       charges  northwest  \
# age
# 18   0.521739  31.326159  0.449275  0.173913   7086.217556   0.000000
# 19   0.514706  28.596912  0.426471  0.264706   9747.909335   0.500000
# 20   0.517241  30.632759  0.862069  0.310345  10159.697736   0.241379
# 21   0.535714  28.185714  0.785714  0.071429   4730.464330   0.250000
# 22   0.535714  31.087679  0.714286  0.214286  10012.932802   0.250000
# 23   0.500000  31.454464  1.000000  0.250000  12419.820040   0.250000
# 24   0.500000  29.142679  0.464286  0.214286  10648.015962   0.250000
# 25   0.535714  29.693929  1.285714  0.178571   9838.365311   0.250000
# 26   0.535714  29.428929  1.071429  0.107143   6133.825309   0.250000
# 27   0.500000  29.333571  0.964286  0.321429  12184.701721   0.214286
# 28   0.500000  29.482143  1.285714  0.107143   9069.187564   0.214286
# 29   0.518519  29.383148  1.259259  0.222222  10430.158727   0.259259
# 30   0.518519  30.557593  1.555556  0.333333  12719.110358   0.222222
# 31   0.518519  29.918333  1.407407  0.185185  10196.980573   0.259259
# 32   0.500000  31.597692  1.269231  0.192308   9220.300291   0.269231
# 33   0.500000  31.163077  1.538462  0.230769  12351.532987   0.230769
# 34   0.500000  30.274038  1.153846  0.192308  11613.528121   0.230769
# 35   0.520000  31.394800  1.680000  0.200000  11307.182031   0.240000
# 36   0.520000  29.374200  1.240000  0.240000  12204.476138   0.240000
# 37   0.520000  31.216600  1.520000  0.360000  18019.911877   0.280000
# 38   0.480000  28.996600  1.480000  0.080000   8102.733674   0.240000
# 39   0.480000  29.910200  2.200000  0.240000  11778.242945   0.240000
# 40   0.518519  30.139074  1.592593  0.185185  11772.251310   0.259259
# 41   0.518519  31.506852  1.407407  0.074074   9653.745650   0.259259
# 42   0.518519  30.328148  1.000000  0.296296  13061.038669   0.222222
# 43   0.481481  30.204444  1.629630  0.444444  19267.278653   0.185185
# 44   0.481481  30.844259  1.222222  0.222222  15859.396587   0.259259
# 45   0.517241  29.778966  1.482759  0.172414  14830.199856   0.241379
# 46   0.517241  31.340862  1.620690  0.172414  14342.590639   0.241379
# 47   0.482759  30.664310  1.379310  0.344828  17653.999593   0.206897
# 48   0.482759  31.925690  1.310345  0.172414  14632.500445   0.241379
# 49   0.500000  30.313929  1.500000  0.142857  12696.006264   0.250000
# 50   0.517241  31.132241  1.310345  0.137931  15663.003301   0.241379
# 51   0.482759  31.727069  1.103448  0.206897  15682.255867   0.206897
# 52   0.482759  32.936034  1.482759  0.206897  18256.269719   0.275862
# 53   0.500000  30.360893  1.250000  0.178571  16020.930755   0.250000
# 54   0.500000  31.234286  1.428571  0.178571  18758.546475   0.250000
# 55   0.500000  31.950000  0.961538  0.076923  16164.545488   0.230769
# 56   0.500000  31.600962  0.769231  0.153846  15025.515837   0.230769
# 57   0.500000  30.844423  0.615385  0.153846  16447.185250   0.269231
# 58   0.480000  32.718200  0.240000  0.040000  13878.928112   0.280000
# 59   0.480000  30.572000  1.200000  0.160000  18895.869532   0.200000
# 60   0.521739  30.332826  0.347826  0.217391  21979.418507   0.217391
# 61   0.478261  32.548261  0.739130  0.260870  22024.457609   0.260870
# 62   0.478261  32.342609  0.565217  0.173913  19163.856573   0.260870
# 63   0.478261  31.923478  0.565217  0.217391  19884.998461   0.260870
# 64   0.500000  32.976136  0.772727  0.318182  23275.530837   0.227273
#
#      southeast  southwest
# age
# 18    0.536232   0.000000
# 19    0.044118   0.455882
# 20    0.275862   0.275862
# 21    0.250000   0.250000
# 22    0.285714   0.214286
# 23    0.250000   0.250000
# 24    0.250000   0.250000
# 25    0.250000   0.250000
# 26    0.250000   0.250000
# 27    0.321429   0.214286
# 28    0.285714   0.250000
# 29    0.259259   0.222222
# 30    0.296296   0.259259
# 31    0.259259   0.222222
# 32    0.307692   0.230769
# 33    0.307692   0.269231
# 34    0.230769   0.269231
# 35    0.240000   0.280000
# 36    0.280000   0.200000
# 37    0.240000   0.240000
# 38    0.280000   0.240000
# 39    0.240000   0.280000
# 40    0.296296   0.185185
# 41    0.296296   0.222222
# 42    0.296296   0.259259
# 43    0.296296   0.259259
# 44    0.296296   0.222222
# 45    0.241379   0.275862
# 46    0.241379   0.241379
# 47    0.310345   0.241379
# 48    0.310345   0.206897
# 49    0.250000   0.250000
# 50    0.241379   0.275862
# 51    0.310345   0.241379
# 52    0.241379   0.241379
# 53    0.250000   0.250000
# 54    0.250000   0.250000
# 55    0.269231   0.269231
# 56    0.230769   0.269231
# 57    0.230769   0.230769
# 58    0.240000   0.240000
# 59    0.320000   0.240000
# 60    0.260870   0.260870
# 61    0.217391   0.260870
# 62    0.260870   0.217391
# 63    0.260870   0.260870
# 64    0.363636   0.227273

# %% [markdown]
# **PRACTICE OPPORTUNITY #2 SOLUTION:**
#  - **Calculate and plot the correlation matrix**
#  - **Which feature has the most positive correlation with charges?**

# %%
plt.figure(figsize = (10, 10))
sns.heatmap(insurance_df.corr(), annot = True)
# smoker and age have positive correlations with charges

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 SOLUTION:**
# - **Split the data into 20% Testing and 80% Training**
# - **Double check that the split was successful by getting the shape of both the training and testing datasets**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

print(X_train.shape)
print(X_test.shape)
# Out:
# (1070, 8)
# (268, 8)

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 SOLUTION:**
# - **Dropout is a regularization technique that is used to improve the network generalization ability. Experiment adding dropout layers to enahnce network generalization ability**
# - **Retrain the network and assess its performance**

# %%
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 8))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 50)                450
# _________________________________________________________________
# activation_4 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 150)               7650
# _________________________________________________________________
# activation_5 (Activation)    (None, 150)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 150)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 150)               22650
# _________________________________________________________________
# activation_6 (Activation)    (None, 150)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 50)                7550
# _________________________________________________________________
# activation_7 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 38,351
# Trainable params: 38,351
# Non-trainable params: 0
# _________________________________________________________________
